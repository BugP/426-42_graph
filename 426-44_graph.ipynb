# %% [markdown]
# 関係するライブラリのインポート

# %%
import pandas as pd, networkx as nx, matplotlib.pyplot as plt
from ortoolpy import chinese_postman, graph_from_table, networkx_draw

# %% [markdown]
# csvをpandasで読んでグラフを作る

# %%
tbn = pd.read_csv('./nodes.csv')
tbe = pd.read_csv('./edges.csv')
g = graph_from_table(tbn, tbe, multi=True)[0]

# %% [markdown]
# csvの中身（indexはpandasによるものなので気にしないでほしい）

# %%
tbn
# Out:
#     id  x   y  demand  weight
# 0    0  0  10       0       1
# 1    1  1  10       0       1
# 2    2  0   9       0       1
# 3    3  1   9       0       1
# 4    4  0   8       0       1
# 5    5  1   8       0       1
# 6    6  0   7       0       1
# 7    7  2   8       0       1
# 8    8  2  10       0       1
# 9    9  3  10       0       1
# 10  10  3   9       0       1
# 11  11  3   8       0       1
# 12  12  2   7       0       1
# 13  13  1   7       0       1
# 14  14  2   6       0       1
# 15  15  1   6       0       1
# 16  16  2   5       0       1
# 17  17  1   4       0       1
# 18  18  2   4       0       1
# 19  19  4   7       0       1
# 20  20  3   6       0       1
# 21  21  5   7       0       1
# 22  22  5   8       0       1
# 23  23  6   7       0       1
# 24  24  4   6       0       1
# 25  25  4   5       0       1
# 26  26  5   6       0       1
# 27  27  6   6       0       1
# 28  28  5   5       0       1

# %%
tbe
# Out:
#     node1  node2  capacity  weight
# 0       0      1         2    11.6
# 1       1      3         2     8.7
# 2       1      8         2    24.2
# 3       2      3         2     5.6
# 4       3      4         2    17.1
# 5       3      5         2    12.9
# 6       4      5         2    11.8
# 7       4      6         2     8.2
# 8       5      7         2     2.8
# 9       7      8         2    25.5
# 10      7     11         2     8.5
# 11      8      9         2    22.3
# 12      8     10         2    20.6
# 13     11     12         2     3.8
# 14     11     19         2    19.1
# 15     12     13         2     1.5
# 16     12     14         2     8.5
# 17     14     15         2    29.7
# 18     14     16         2    30.8
# 19     16     17         2    13.9
# 20     16     18         2     6.5
# 21     19     20         2    18.5
# 22     19     21         2    17.1
# 23     19     24         2     4.8
# 24     21     22         2    15.2
# 25     21     23         2     4.2
# ...

# %% [markdown]
# グラフの図示

# %%
networkx_draw(g)
plt.show()

# %% [markdown]
# 中国人郵便配達問題を解く（途中，(25, 6)が存在するのでそこから読み始めること）

# %%
print(chinese_postman(g))
# Out:
# (716.4000000000002, [(0, 1), (1, 8), (8, 10), (10, 9), (9, 8), (8, 7), (7, 5), (5, 7), (7, 11), (11, 13), (13, 12), (12, 16), (16, 18), (18, 17), (17, 16), (16, 14), (14, 15), (15, 14), (14, 12), (12, 11), (11, 19), (19, 21), (21, 23), (23, 22), (22, 21), (21, 20), (20, 19), (19, 24), (24, 27), (27, 26), (26, 28), (28, 26), (26, 24), (24, 25), (25, 6), (6, 4), (4, 5), (5, 3), (3, 4), (4, 2), (2, 3), (3, 1), (1, 0)])

# %% [markdown]
# ただし，各IDは以下の駅に対応する．
#
# 0. 新羽島
# 1. 笠松
# 2. 玉ノ井
# 3. 一宮
# 4. 津島
# 5. 須ケ口
# 6. 弥富
# 7. 東枇杷島
# 8. 犬山
# 9. 御嵩
# 10. 上飯田
# 11. 神宮前
# 12. 大江
# 13. 東名古屋港
# 14. 太田川
# 15. 中部国際空港
# 16. 富貴
# 17. 内海
# 18. 河和
# 19. 知立
# 20. 碧南
# 21. 梅坪
# 22. 赤池
# 23. 猿投
# 24. 新安城
# 25. 蒲郡
# 26. 国府
# 27. 豊川稲荷
# 28. 豊橋

# %% [markdown]
# このnotebookのコードは，[組合せ最適化 - 典型問題 - 中国人郵便配達問題](https://qiita.com/SaitoTsutomu/items/6b8e4a9c794ff8be110f)そのままである．
